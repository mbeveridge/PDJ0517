# %%
import pandas as pd

# %%
committees = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
committees.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
committees_NNN = committees[committees.prop_name == "PROPOSITION 054 - LEGISLATURE. LEGISLATION AND PROCEEDINGS. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE."]

# %%
committees_NNN.head(6)
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 11  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 12  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 13  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 14  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
#
#     ccdc_prop_id                                          prop_name  \
# 11            73  PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 12            73  PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 13            73  PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 14            73  PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 11                396                 1389997
# 12                393                 1381029
# 13                394                 1386494
# 14                395                 1385928
#
# ...

# %%
committees_NNN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 11 to 14
# Data columns (total 8 columns):
# ocd_prop_id               4 non-null object
# calaccess_prop_id         4 non-null int64
# ccdc_prop_id              4 non-null int64
# prop_name                 4 non-null object
# ccdc_committee_id         4 non-null int64
# calaccess_committee_id    4 non-null int64
# committee_name            4 non-null object
# committee_position        4 non-null object
# dtypes: int64(4), object(4)
# memory usage: 288.0+ bytes

# %%
contributions = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
contributions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
merged_NNN = pd.merge(committees_NNN, contributions, on="calaccess_committee_id")

# %%
merged_NNN.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 1  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 2  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 3  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 4  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
#
#    ccdc_prop_id                                          prop_name  \
# 0            73  PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 1            73  PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 2            73  PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 3            73  PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 4            73  PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                396                 1389997
# ...

# %%
merged_NNN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 0 to 31
# Data columns (total 20 columns):
# ocd_prop_id                     32 non-null object
# calaccess_prop_id               32 non-null int64
# ccdc_prop_id                    32 non-null int64
# prop_name                       32 non-null object
# ccdc_committee_id               32 non-null int64
# calaccess_committee_id          32 non-null int64
# committee_name_x                32 non-null object
# committee_position              32 non-null object
# committee_name_y                32 non-null object
# calaccess_filing_id             32 non-null int64
# date_received                   32 non-null object
# contributor_lastname            32 non-null object
# contributor_firstname           20 non-null object
# contributor_city                32 non-null object
# contributor_state               32 non-null object
# contributor_zip                 32 non-null object
# ...

# %%
merged_NNN.amount.sum()
# Out:
# 152178.96000000002

# %%
merged_NNN.committee_position.value_counts()
# Out:
# SUPPORT    32
# Name: committee_position, dtype: int64

# %%
support_NNN = merged_NNN[merged_NNN.committee_position == "SUPPORT"]

# %%
oppose_NNN = merged_NNN[merged_NNN.committee_position == "OPPOSE"]

# %%
support_NNN.amount.sum()
# Out:
# 152178.96000000002

# %%
oppose_NNN.amount.sum()
# Out:
# 0

# %%
support_NNN.amount.sum() / merged_NNN.amount.sum()
# Out:
# 1.0

# %%
merged_NNN.sort_values("amount")
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 2   ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 16  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 4   ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 6   ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 7   ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 0   ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 1   ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 5   ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 21  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 14  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 13  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 11  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# ...

# %%
merged_NNN.sort_values("amount", ascending=False)
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 26  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 25  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 30  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 18  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 28  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 15  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 17  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 22  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 24  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 27  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 29  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# 23  ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# ...

# %%
oppose_NNN.sort_values("amount", ascending=False).head()
# Out:
# Empty DataFrame
# Columns: [ocd_prop_id, calaccess_prop_id, ccdc_prop_id, prop_name, ccdc_committee_id, calaccess_committee_id, committee_name_x, committee_position, committee_name_y, calaccess_filing_id, date_received, contributor_lastname, contributor_firstname, contributor_city, contributor_state, contributor_zip, contributor_employer, contributor_occupation, contributor_is_self_employed, amount]
# Index: []

# %%
merged_NNN.groupby("committee_name_x")

# %%
merged_NNN.groupby("committee_name_x").amount.sum().reset_index()
# Out:
#                                     committee_name_x    amount
# 0  CALIFORNIA COMMON CAUSE -- YES ON 54 AND 59 (N...  50388.84
# 1  PROTEUS ACTION LEAGUE NON-PROFIT 501 (C)(4) OR...  96790.12
# 2  YES ON 54 - VOTERS FIRST, NOT SPECIAL INTEREST...   5000.00

# %%
merged_NNN.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                                     committee_name_x    amount
# 1  PROTEUS ACTION LEAGUE NON-PROFIT 501 (C)(4) OR...  96790.12
# 0  CALIFORNIA COMMON CAUSE -- YES ON 54 AND 59 (N...  50388.84
# 2  YES ON 54 - VOTERS FIRST, NOT SPECIAL INTEREST...   5000.00

# %%
merged_NNN.groupby(["contributor_firstname", "contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#    contributor_firstname contributor_lastname committee_position   amount
# 1                 DAGMAR                DOLBY            SUPPORT  15000.0
# 17                THOMAS                MOWRY            SUPPORT    250.0
# 14               MICHAEL               MARMOR            SUPPORT    250.0
# 0                  BRUCE              STENMAN            SUPPORT    200.0
# 3                  DEREK             CRESSMAN            SUPPORT    159.0
# 2                DARLENE               LITTLE            SUPPORT    159.0
# 16                   ROY               MAFFLY            SUPPORT    159.0
# 9                   JOHN               GARVEY            SUPPORT    159.0
# 7                  JAMES             MORRISON            SUPPORT    118.0
# 10                JUDITH               WEINER            SUPPORT    118.0
# 4                    DON             COTTRELL            SUPPORT    100.0
# 5                  EDITH         ANDREW-AKITA            SUPPORT    100.0
# ...

# %%
merged_NNN.groupby(["contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                contributor_lastname committee_position    amount
# 21  THE ATLANTIC ADVOCACY FUND INC.            SUPPORT  60000.00
# 2           CALIFORNIA COMMON CAUSE            SUPPORT  19098.84
# 22           VOQAL USA PHILANTHROPY            SUPPORT  15000.00
# 6                             DOLBY            SUPPORT  15000.00
# 17                     PROTEUS FUND            SUPPORT  14000.00
# 16            PROTEUS ACTION LEAGUE            SUPPORT  14000.00
# 20   THE ATLANTIC ADVOCACY FUND INC            SUPPORT   6723.62
# 15      NEW MAJORITY CALIFORNIA PAC            SUPPORT   5000.00
# 19       THE ATLANTIC ADVOCACY FUND            SUPPORT   1066.50
# 14                            MOWRY            SUPPORT    250.00
# 12                           MARMOR            SUPPORT    250.00
# 18                          STENMAN            SUPPORT    200.00
# 11                           MAFFLY            SUPPORT    159.00
# ...

# %%
whos
# Out:
# Variable         Type         Data/Info
# ---------------------------------------
# committees       DataFrame                             <...>n\n[102 rows x 8 columns]
# committees_NNN   DataFrame                             <...>TURE             OPPOSE
# contributions    DataFrame           calaccess_committe<...>[56379 rows x 13 columns]
# merged_NNN       DataFrame                             <...>        False   1066.50
# oppose_NNN       DataFrame    Empty DataFrame\nColumns:<...>loyed, amount]\nIndex: []
# pd               module       <module 'pandas' from '/U<...>ages/pandas/__init__.py'>
# support_NNN      DataFrame                             <...>        False   1066.50
