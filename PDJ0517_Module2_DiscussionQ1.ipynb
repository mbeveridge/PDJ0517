# %%
import pandas as pd

# %%
contributions = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
contributions.head()
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
# 3              2083796    2016-08-10      WARREN-SAMARIPA
# 4              2083796    2016-07-26      WARREN-SAMARIPA
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# ...

# %%
contributions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %% [markdown]
# 68 rows of col=calaccess_committee_id...

# %%
contributions.calaccess_committee_id.value_counts().reset_index()
# Out:
#       index  calaccess_committee_id
# 0   1302403                   28617
# 1   1329332                    6054
# 2   1380675                    5457
# 3   1380590                    4105
# 4   1380746                    2662
# 5   1382067                    2631
# 6   1346266                    1014
# 7   1374469                     866
# 8   1376791                     692
# 9   1390529                     690
# 10  1220380                     656
# 11  1343793                     420
# 12  1386909                     318
# 13  1387279                     275
# 14  1381808                     250
# 15  1381423                     204
# 16  1378875                     184
# 17  1386627                     146
# 18  1372900                     128
# 19  1379198                     111
# 20  1385139                      94
# 21  1382568                      88
# 22  1377991                      81
# 23  1383946                      69
# 24  1381382                      48
# ...

# %% [markdown]
# 76 rows of col=committee_name (which should presumably be 68? #3 + #4 =6054)...

# %%
contributions.committee_name.value_counts().reset_index()
# Out:
#                                                 index  committee_name
# 0   CALIFORNIA CORRECTIONAL PEACE OFFICERS ASSOCIA...           28617
# 1   NEWSOM BALLOT MEASURE COMMITTEE; SAFETY FOR AL...            5457
# 2   YES ON 62, NO ON 66. REPLACE THE COSTLY, FAILE...            4105
# 3   COMMITTEE TO DEFEAT PROP 23, SPONSORED BY ENVI...            3027
# 4   SAVE THE BAG BAN, YES ON 67, SPONSORED BY ENVI...            3027
# 5   STOP PROP 63, A GRASSROOTS, COMMON-SENSE EFFOR...            2662
# 6   COALITION FOR CIVIL LIBERTIES - NO ON 63, A PR...            2631
# 7   YES ON PROPOSITION 51 - CALIFORNIANS FOR QUALI...             866
# 8   YES ON PROP 61, CALIFORNIANS FOR LOWER DRUG PR...             692
# 9                            VOLUNTEERS FOR YES ON 62             690
# 10  CALIFORNIANS TO MEND, NOT END, THE DEATH PENAL...             507
# 11  CALIFORNIANS FOR JUSTICE AND PUBLIC SAFETY, NO...             507
# ...

# %% [markdown]
# 258 rows of col=calaccess_filing_id (which should presumably be 68? Or 76?)...

# %%
contributions.calaccess_filing_id.value_counts().reset_index()
# Out:
#        index  calaccess_filing_id
# 0    2013304                28612
# 1    2083720                 3015
# 2    1979246                 1322
# 3    2083707                 1292
# 4    2082835                  999
# 5    2012736                  974
# 6    2064720                  930
# 7    1997835                  894
# 8    2130864                  857
# 9    2064020                  802
# 10   2061823                  762
# 11   2082426                  740
# 12   2098615                  707
# 13   2098423                  694
# 14   2097541                  686
# 15   2097584                  681
# 16   2082753                  646
# 17   2063076                  576
# 18   2129919                  543
# 19   2113515                  508
# 20   2098515                  501
# 21   2038645                  482
# 22   2064651                  464
# 23   2033917                  445
# 24   2054483                  432
# 25   2038035                  419
# ...

# %% [markdown]
# 590 rows of col=date_received. Vast majority on 16Dec2015. (#562 is Nov2017 in future. #565 is 1000yrs in past. #566 is 100yrs in future. #583 is Aug2018)

# %%
contributions.date_received.value_counts().reset_index()
# Out:
#           index  date_received
# 0    2015-12-16          28618
# 1    2016-11-03            536
# 2    2016-10-18            518
# 3    2016-10-03            484
# 4    2016-06-03            459
# 5    2016-06-18            414
# 6    2015-12-18            402
# 7    2016-09-18            397
# 8    2015-12-03            394
# 9    2016-09-03            365
# 10   2016-10-07            342
# 11   2016-09-22            305
# 12   2016-10-12            251
# 13   2016-09-23            248
# 14   2016-09-29            240
# 15   2016-08-12            229
# 16   2016-11-04            227
# 17   2016-09-30            222
# 18   2016-06-24            219
# 19   2016-09-15            219
# 20   2016-09-14            211
# 21   2016-08-31            207
# 22   2016-09-16            207
# 23   2016-10-17            205
# 24   2016-10-11            202
# 25   2016-10-13            192
# 26   2016-10-27            186
# 27   2016-05-03            184
# 28   2016-08-25            176
# ...

# %%
contributions.amount.value_counts().reset_index()
# Out:
#           index  amount
# 0        287.08   28612
# 1        100.00    7604
# 2         25.00    3749
# 3         50.00    3184
# 4       1000.00     974
# 5        250.00     950
# 6         15.00     920
# 7         10.00     900
# 8        500.00     723
# 9        150.00     556
# 10        60.00     528
# 11         5.00     505
# 12       200.00     499
# 13        20.00     413
# 14      5000.00     360
# 15        75.00     333
# 16        45.00     297
# 17        35.00     233
# 18       185.00     232
# 19       120.00     227
# 20        90.00     198
# 21      2000.00     194
# 22     10000.00     182
# 23      2500.00     181
# 24       130.00     179
# 25       105.00     161
# 26        30.00     151
# 27     50000.00     144
# 28     25000.00     142
# 29       300.00     117
# ..          ...     ...
# 435      375.00       1
# 436     1609.75       1
# 437   137500.00       1
# 438   205955.00       1
# 439    -2450.00       1
# 440   900000.00       1
# ...

# %%
contrib_amount = contributions.amount.reset_index()

# %%
contrib_amount.describe()
# Out:
#              index        amount
# count  56379.00000  5.637900e+04
# mean   28189.00000  7.254136e+03
# std    16275.35975  1.588498e+05
# min        0.00000 -1.500000e+05
# 25%    14094.50000  1.000000e+02
# 50%    28189.00000  2.870800e+02
# 75%    42283.50000  2.870800e+02
# max    56378.00000  1.250000e+07

# %%
contrib_amount.sum()
# Out:
# index     1.589268e+09
# amount    4.089809e+08
# dtype: float64
